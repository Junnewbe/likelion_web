# %% [markdown]
# ## 시각화
#     * matplotlib:시각화
#     * seaborn : 0.11-48그래프
#     * plotly
#     * 지도 시각화: google map,->...->folium
#     * plotline
#     * d3.js

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
print(matplotlib.__version__)
# Out:
# 3.3.2

# %%
plt.plot([1,2,3,4,5], 'o') # '-' 선 : 기본값 #x&y 안 설정하면 y값으로 들어감

plt.show()

# %%
y = np.array([3, 3, 1, 20, 10])
plt.plot(y , marker = 'o', ms=15, mec = 'r', mfc='g')
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(1,3,1) # 1행 3열 의 것중에 첫번째
ax2 = fig.add_subplot(1,3,2) # 1행 3열 의 것중에 두번째
ax3 = fig.add_subplot(1,3,3) # 1행 3열 의 것중에 두번째
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
x=range(0,100)
y=[v*v for v in x]
ax1.plot(x,y)
ax2.bar(x,y)
plt.show()

# %% [markdown]
# # index= 행의 아이디
#     *columns=[]

# %%
import seaborn as sns
from pandas import DataFrame
tips=sns.load_dataset("tips")

# %%
tips.loc[1:5,"tip":"day"]
tips.iloc[1:6,1:5 ]

# %%
print(tips.tip.min())
print(tips.tip.max())
print(tips.tip.count())
print(tips.tip.std()) #var에 루트씨운거(표준 편차)
print(tips.tip.var()) #분산
print(tips.tip.sum())
print(tips.tip.median())
print( tips.tip.abs() )           # 값들의 절대값 구하기
print("========================")
print( tips.tip.max() )           # 최대값()
print( tips.tip.argmax() )        # 최대값의 위치
print( tips.tip.idxmax() )        # 최대값의 인덱스값
print()
print( tips.iloc[170:171, :])
print("========================")
print( tips.tip.cumsum() )        # 누적합계
print("========================")
print( tips.tip.size )            # 크기

# %%
iris['all_sum'] = iris.sum(axis=1) #현재는 행의 합 하지만 axis=0하면 열릐합 가능!
iris
# team_df.rowsum.sort_values(ascending=False) 데이터 프레임 발류 크기로 정렬

# %%
import pandas as pd
test=pd.read_csv("./california_housing_test.csv")
train=pd.read_csv("./california_housing_train.csv")

# %%
test.head(7)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# ...

# %%
train.head(7)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
train.describe() #info(), columns,shape,head(),
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import matplotlib.pyplot as plt
train.hist(bins=50,figsize=(20,15)) #bins 막대 넓이 조절
# Out:
# array([[<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'housing_median_age'}>],
#        [<AxesSubplot:title={'center':'total_rooms'}>,
#         <AxesSubplot:title={'center':'total_bedrooms'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'households'}>,
#         <AxesSubplot:title={'center':'median_income'}>,
#         <AxesSubplot:title={'center':'median_house_value'}>]],
#       dtype=object)

# %%
train.plot(kind='scatter',
          x='longitude', y='latitude',
          alpha=0.8,
          s=train['population']/100,
          c='median_house_value',
          cmap=plt.get_cmap('jet'),
          colorbar=True,
          figsize=(12,10)) #s는 점의 크기, alpha는 진하기 정도??
#.get_cmap은 원하는 색 넘기는 함수!
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
test.plot(kind='scatter',
          x='longitude', y='latitude',
          alpha=0.1,
          s=test['population']/100,
          c='median_house_value',
          cmap=plt.get_cmap('jet'),
          colorbar=True) #s는 점의 크기
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
sel=['total_rooms','total_bedrooms','population']
temp_train=train[sel]
temp_train
# Out:
#        total_rooms  total_bedrooms  population
# 0           5612.0          1283.0      1015.0
# 1           7650.0          1901.0      1129.0
# 2            720.0           174.0       333.0
# 3           1501.0           337.0       515.0
# 4           1454.0           326.0       624.0
# ...            ...             ...         ...
# 16995       2217.0           394.0       907.0
# 16996       2349.0           528.0      1194.0
# 16997       2677.0           531.0      1244.0
# 16998       2672.0           552.0      1298.0
# 16999       1820.0           300.0       806.0
#
# [17000 rows x 3 columns]

# %%
temp_train.describe()
# Out:
#         total_rooms  total_bedrooms    population
# count  17000.000000    17000.000000  17000.000000
# mean    2643.664412      539.410824   1429.573941
# std     2179.947071      421.499452   1147.852959
# min        2.000000        1.000000      3.000000
# 25%     1462.000000      297.000000    790.000000
# 50%     2127.000000      434.000000   1167.000000
# 75%     3151.250000      648.250000   1721.000000
# max    37937.000000     6445.000000  35682.000000

# %% [markdown]
# ## 십습 37937이 어디 위치하는지 찾기!

# %%
x=0
for i in temp_train['total_rooms']:
    x+=1
    if i==37937:
        print(x)
# Out:
# 2872

# %%
max_room=train.loc[train['total_rooms']==37937,:] #loc안에 조건문 사용가능!
max_room #일단 암기??
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2871    -117.74     33.89                 4.0      37937.0          5471.0
#
#       population  households  median_income  median_house_value
# 2871     16122.0      5189.0         7.4947            366300.0

# %%
import seaborn as sns
fig=plt.figure(figsize=(12,10))

plt.subplot(3,1,1)
sns.boxplot(x="total_rooms", data=temp_train)
plt.subplot(3,1,2)
sns.boxplot(x="total_bedrooms", data=temp_train)
plt.subplot(3,1,3)
sns.boxplot(x="population", data=temp_train)
# Out:
# <AxesSubplot:xlabel='population'>

# %%
sns.pairplot(temp_train)

# %%
temp_train.corr()# 상관도!!!!!
# Out:
#                 total_rooms  total_bedrooms  population
# total_rooms        1.000000        0.928403    0.860170
# total_bedrooms     0.928403        1.000000    0.881169
# population         0.860170        0.881169    1.000000

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,3,1) 
sns.boxplot(x="total_rooms", data=train)
plt.subplot(3,3,2) 
sns.boxplot(x="total_bedrooms", data=train)
plt.subplot(3,3,3) 
sns.boxplot(x="population", data=train)  
plt.subplot(3,3,4) 
sns.boxplot(x="longitude", data=train)
plt.subplot(3,3,5) 
sns.boxplot(x="latitude", data=train)
plt.subplot(3,3,6) 
sns.boxplot(x="households", data=train)  
plt.subplot(3,3,7) 
sns.boxplot(x="median_income", data=train)
plt.subplot(3,3,8) 
sns.boxplot(x="median_house_value", data=train)
# Out:
# <AxesSubplot:xlabel='median_house_value'>

# %%
plt.figure(figsize=(10,10))
for x in range(8):
    plt.subplot(3,3,x+1) 
    sns.boxplot(x=train.columns[x], data=train)

# %%
#예준님 코드
# plt.figure(figsize=(10,10), facecolor='white')
# for i in range(1, 9):
#     graph = input('>>> ')
#     if graph=='q': break
#     plt.subplot(3,3,i) 
#     sns.boxplot(x=graph, data=cali_train)
# Out:
#   File "<ipython-input-53-da32db5d3672>", line 1
#     예준님 코드
#         ^
# SyntaxError: invalid syntax

# %%
#효진님꺼 분석요망!!!
# trainColumns=list(train.columns)
# trainColumns.pop(2)
# trainColumns
# for (idx,i) in enumerate(trainColumns):
#   plt.subplot(3,3,idx+1)
#   sns.boxplot(x=i,data=train)

# %%
## 두 컬럼 선택 
temp02 = train.loc[:,  [ "median_income", "median_house_value" ] ]
temp02.head()
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %%
## 두 컬럼 선택 8열, 9열
temp03 = train.iloc[:,  [7, 8] ]
print( temp03.head() )
temp03 = train.iloc[:,  [-2, -1] ]
print( temp03.head() )
# Out:
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0
#    median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0

# %%
train.total_rooms.describe()
# Out:
# count    17000.000000
# mean      2643.664412
# std       2179.947071
# min          2.000000
# 25%       1462.000000
# 50%       2127.000000
# 75%       3151.250000
# max      37937.000000
# Name: total_rooms, dtype: float64

# %%
## group1 3151 큰놈
## group2 2127~3150 
## group3 1462~2126
## group3 ~1462
tmp_A1=train.loc[train['total_rooms']>=3151,:]
tmp_A2=train.loc[(train['total_rooms']>=2127)&(train['total_rooms']<3151),:]
tmp_A3=train.loc[(train['total_rooms']>=1462)&(train['total_rooms']<2127),:]
tmp_A4=train.loc[(train['total_rooms']<1462),:]

tmp_A1.shape, tmp_A2.shape, tmp_A3.shape, tmp_A4.shape,
# Out:
# ((4250, 9), (4257, 9), (4247, 9), (4245, 9))

# %%
a=4250+4257+4247+4245
print(a)
# Out:
# 16999

# %%
train.loc[train['total_rooms']>=3151,"room_level"] = 1
train.loc[(train['total_rooms']>=2127)&(train['total_rooms']<3151),"room_level"] = 2
train.loc[(train['total_rooms']>=1462)&(train['total_rooms']<2127),"room_level"] = 3
train.loc[(train['total_rooms']<1462),"room_level"] = 4

# %%
train.head(7)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value room_level
# 0      1015.0       472.0         1.4936             66900.0        1.0
# 1      1129.0       463.0         1.8200             80100.0        1.0
# 2       333.0       117.0         1.6509             85700.0        4.0
# 3       515.0       226.0         3.1917             73400.0        3.0
# ...

# %% [markdown]
# # 실습
#     *테스트 데이터 셋도 동일한 기준으로 1,2,3,4나누기

# %%
test.total_rooms.describe()
# Out:
# count     3000.000000
# mean      2599.578667
# std       2155.593332
# min          6.000000
# 25%       1401.000000
# 50%       2106.000000
# 75%       3129.000000
# max      30450.000000
# Name: total_rooms, dtype: float64

# %%
test.loc[train['total_rooms']>=3151,"room_level"] = 1
test.loc[(train['total_rooms']>=2127)&(train['total_rooms']<3151),"room_level"] = 2
test.loc[(train['total_rooms']>=1462)&(train['total_rooms']<2127),"room_level"] = 3
test.loc[(train['total_rooms']<1462),"room_level"] = 4

# %%
test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value  room_level  \
# 0      1537.0       606.0         6.6085            344700.0         1.0
# 1       809.0       277.0         3.5990            176500.0         1.0
# 2      1484.0       495.0         5.7934            270500.0         4.0
# 3        49.0        11.0         6.1359            330000.0         3.0
# 4       850.0       237.0         2.9375             81700.0         4.0
#
#    bedroom_level
# 0            4.0
# 1            4.0
# 2            4.0
# 3            4.0
# ...

# %% [markdown]
# # 실습2

# %%
train.total_bedrooms.describe()
# Out:
# count    17000.000000
# mean       539.410824
# std        421.499452
# min          1.000000
# 25%        297.000000
# 50%        434.000000
# 75%        648.250000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
test.loc[test['total_bedrooms']>=648,"bedroom_level"] = 1
test.loc[(test['total_bedrooms']>=434)&(train['total_rooms']<648),"bedroom_level"] = 2
test.loc[(test['total_bedrooms']>=297)&(train['total_rooms']<434),"bedroom_level"] = 3
test.loc[(test['total_bedrooms']<297),"bedroom_level"] = 4

# %%
test.head() #inplcae& drop 확인!!!
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value  room_level  \
# 0      1537.0       606.0         6.6085            344700.0         1.0
# 1       809.0       277.0         3.5990            176500.0         1.0
# 2      1484.0       495.0         5.7934            270500.0         4.0
# 3        49.0        11.0         6.1359            330000.0         3.0
# 4       850.0       237.0         2.9375             81700.0         4.0
#
#    bedroom_level
# 0            1.0
# 1            4.0
# 2            4.0
# 3            4.0
# ...

# %% [markdown]
#  # inplcae& drop 확인!!!

# %%
train['room_level']=train.room_level.astype("category") #카테고리는 범주형!!
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
#  9   room_level          17000 non-null  category
# dtypes: category(1), float64(9)
# memory usage: 1.2 MB

# %%
sns.boxplot(x='room_level',y='housing_median_age',data=train)
# Out:
# <AxesSubplot:xlabel='room_level', ylabel='housing_median_age'>

# %%
sns.barplot(x='room_level',y='housing_median_age',data=train)
# Out:
# <AxesSubplot:xlabel='room_level', ylabel='housing_median_age'>

# %%
sns.barplot(x='room_level',y='median_income',data=train)
# Out:
# <AxesSubplot:xlabel='room_level', ylabel='median_income'>
