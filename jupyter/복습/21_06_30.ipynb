# %%
print("hi")
# Out:
# hi

# %%
import plotly
import cufflinks as cf
import numpy as np
import pandas as pd
import sys
import seaborn as sns

# %%
print(sys.version)
print(plotly.__version__)
print(cf.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# 5.1.0
# 0.17.3
# 1.1.3
# 1.19.2

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True) #오프라인 모드에서도 인터랙티브 그래픽가능!
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
### 데이터 생성 및 plot
dat=np.random.randn(100,4)
df=pd.DataFrame(dat, columns=['A', 'B', 'C', 'D'])
print(df.shape)
df.head()
# Out:
# (100, 4)
#           A         B         C         D
# 0 -0.622425 -1.318497 -0.597400  1.416570
# 1 -1.963227 -1.132724  0.881628  1.064692
# 2 -0.752053  1.372451  0.394762  0.816182
# 3  0.459468 -0.771777 -0.754128  0.895785
# 4  0.742743 -0.414263  0.885427  0.069587

# %%
df2 = pd.DataFrame({'items':['bag','apple','cap'],
                    'Values':[32,43,50,]})
df2
# Out:
#    items  Values
# 0    bag      32
# 1  apple      43
# 2    cap      50

# %%
df.loc[:,"A":"C"].iplot(kind='line' ,title="제목", xTitle="x축", yTitle="y축")
# Out:
# <div>                            <div id="0cc02d1d-934a-42ae-8402-6b17508c7402" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['B','D']].iplot(kind='line')
# Out:
# <div>                            <div id="08d2ecab-240a-4b22-83e4-abaaaa9527da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Ir=sns.load_dataset("iris")

# %%
Ir.iplot(kind='line')
# Out:
# <div>                            <div id="a8a64dc8-339c-4f9b-bf52-28eff4698e94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Ir.iplot(kind='bar')
# Out:
# <div>                            <div id="f0941d07-18d9-4529-a470-f5293fc53884" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Ir.iplot(kind='barh', barmode='stack')
# Out:
# <div>                            <div id="563a6c00-d50b-400d-b867-77353a48be52" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Scatter plot두 변수간에 상관 관계를 볼때

# %%
df.iplot(kind='scatter', x='A',y='B',mode='lines+markers',size=20)
# Out:
# <div>                            <div id="0dac7799-6627-48fa-90d4-1b11a5ddc1e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter', x='A',y='B',mode='markers',
size=20, color='#3f9142', symbol=19) #심볼은 마커모양 변화줌
# Out:
# <div>                            <div id="c70780bb-3664-4202-965e-f87c18db24ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## 실습1-2 A,C선택후 산점도 그린다 그리고 모드&사이즈 변경

# %%
df.iplot(kind='scatter', x='A',y='C',mode='lines+markers',
size=10, color='red', symbol=12) #심볼은 마커모양 변화줌
# Out:
# <div>                            <div id="a7e30226-452e-4836-93dd-83b4cfc5b16c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
from plotly.validators.scatter.marker import SymbolValidator
raw_symbols = SymbolValidator().values
raw_symbols
# Out:
# [0,
#  '0',
#  'circle',
#  100,
#  '100',
#  'circle-open',
#  200,
#  '200',
#  'circle-dot',
#  300,
#  '300',
#  'circle-open-dot',
#  1,
#  '1',
#  'square',
#  101,
#  '101',
#  'square-open',
#  201,
#  '201',
#  'square-dot',
#  301,
#  '301',
#  'square-open-dot',
#  2,
#  '2',
#  'diamond',
#  102,
#  '102',
#  'diamond-open',
#  202,
#  '202',
#  'diamond-dot',
#  302,
#  '302',
#  'diamond-open-dot',
#  3,
#  '3',
#  'cross',
#  103,
#  '103',
#  'cross-open',
#  203,
#  '203',
#  'cross-dot',
#  303,
#  '303',
#  'cross-open-dot',
#  4,
#  '4',
#  'x',
#  104,
#  '104',
#  'x-open',
#  204,
#  '204',
#  'x-dot',
#  304,
#  '304',
#  'x-open-dot',
#  5,
#  '5',
#  'triangle-up',
#  105,
#  '105',
#  'triangle-up-open',
#  205,
#  '205',
#  'triangle-up-dot',
#  305,
#  '305',
#  'triangle-up-open-dot',
#  6,
#  '6',
#  'triangle-down',
#  106,
#  '106',
#  'triangle-down-open',
#  206,
#  '206',
#  'triangle-down-dot',
#  306,
#  '306',
#  'triangle-down-open-dot',
#  7,
# ...

# %%
df2.iplot(kind='bar',x='items',y='Values')
# Out:
# <div>                            <div id="3d3712cf-7751-47dc-9997-96ffe37804ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
Ir.iplot(kind='bar', x='species',y='petal_length',title="petal_leng", xTitle="x축", yTitle="y축")
# Out:
# <div>                            <div id="3dba6fb9-d648-48e7-a379-0ef9fc579edd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# setosa가 꽃잎 길이가 가장 짧다?

# %%
Ir.iplot(kind='bar', x='species',y='sepal_width',title="sepal_width", xTitle="x축", yTitle="y축")
# Out:
# <div>                            <div id="60f5a312-9f42-49de-a24f-2b5e74785f2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#setosa가 꽃받침 가장 두껍다

# %%
Ir.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sl=Ir['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
sw=sl=Ir['sepal_width'].mean()
sl=Ir['sepal_length'].mean()
pl=Ir['petal_length'].mean()
pw=Ir['petal_width'].mean()

# %%
df2 = pd.DataFrame({'items':['Sw','Sl','Pl','Pw'],
                    'Values':[sw,sl,pl,pw]})
df2
# Out:
#   items    Values
# 0    Sw  3.057333
# 1    Sl  5.843333
# 2    Pl  3.758000
# 3    Pw  1.199333

# %%
df2.iplot(kind='bar',x='items',y='Values')
# Out:
# <div>                            <div id="65388a7f-057f-4c4f-95f5-6061d2fd1a74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## sepal_length의 평균길이가 가장 길다

# %%
Ir.iplot(kind='bar', x='species', y=['sepal_width','petal_length'], xTitle='Species', yTitle = 'S&P')
# Out:
# <div>                            <div id="cbb0db6d-c896-463d-b026-685686904039" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar')
# Out:
# <div>                            <div id="627998e6-8a4f-4b18-b510-e527e4eb0831" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="2982d213-3d5a-4c80-a6a0-003be76fcd2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],
'y':[10,20,30,40,60],
'z':[5,4,3,2,1]})
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  40  2
# 4  5  60  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>                            <div id="f4717d9d-f93b-44ab-b7e4-96e9bbd3f1c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df = cf.datagen.lines()
df.shape
# Out:
# (100, 5)

# %%
df.iplot(kind='line')
# Out:
# <div>                            <div id="bd774861-1442-4da8-af38-612a75385165" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB
